# %% [markdown]
# <a href="https://colab.research.google.com/github/klv8688-bit/variables/blob/main/d1_%E8%AE%8A%E6%95%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=1

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
b="bcd"

# %%
print(type(b))
# Out:
# <class 'str'>

# %%
c=12.34

# %%
print(type(c))
# Out:
# <class 'float'>

# %%
d=True

# %%
print(type(d))
# Out:
# <class 'bool'>
